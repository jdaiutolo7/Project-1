# %%
# Import libraries
import pandas as pd
from pathlib import Path

# Store filepath in a variable
file = Path("Resources/listings.csv.gz")
file_df = pd.read_csv(file)
file_df
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_11464\2934771585.py:7: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_df = pd.read_csv(file)
#                        id                                      listing_url  \
# 0      801749842377802394  https://www.airbnb.com/rooms/801749842377802394
# 1      765948794133787266  https://www.airbnb.com/rooms/765948794133787266
# 2      636274456676328779  https://www.airbnb.com/rooms/636274456676328779
# 3      768125251187660469  https://www.airbnb.com/rooms/768125251187660469
# 4                49248255            https://www.airbnb.com/rooms/49248255
# ...                   ...                                              ...
# 42926            40342902            https://www.airbnb.com/rooms/40342902
# 42927            35257699            https://www.airbnb.com/rooms/35257699
# 42928            52491515            https://www.airbnb.com/rooms/52491515
# ...

# %%
smaller_file_df = file_df[["id",	"host_id", "host_name",	"neighbourhood_cleansed", "neighbourhood_group_cleansed", "latitude", "longitude", "property_type", "room_type",
"accommodates", "bathrooms_text", "bedrooms", "beds", "price", "number_of_reviews", "review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness",
"review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value"]]

smaller_file_df
# Out:
#                        id    host_id     host_name neighbourhood_cleansed  \
# 0      801749842377802394  495455523       Michael               Canarsie
# 1      765948794133787266  488760226          Eric               Canarsie
# 2      636274456676328779  461263600       Tommaso            Tottenville
# 3      768125251187660469  475699129       Suliman         Sheepshead Bay
# 4                49248255  397288055     Katherine        North Riverdale
# ...                   ...        ...           ...                    ...
# 42926            40342902   90429772         Hanna           East Village
# 42927            35257699  264962468          Mili         Hell's Kitchen
# 42928            52491515  305489297       Stavros        Lower East Side
# 42929            48158801    6600525       Quentin               Bushwick
# 42930            48316258  219517861  Sonder (NYC)      Flatiron District
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# ...

# %%
smaller_file_df.to_csv("Resources/NewYorkAirBnB.csv")
